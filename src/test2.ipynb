# %%
import copernicusmarine

# %%
copernicusmarine.subset
# Out:
# <function copernicusmarine.python_interface.subset.subset(dataset_id: str | None = None, dataset_version: str | None = None, dataset_part: str | None = None, username: str | None = None, password: str | None = None, variables: list[str] | None = None, minimum_longitude: float | None = None, maximum_longitude: float | None = None, minimum_latitude: float | None = None, maximum_latitude: float | None = None, minimum_depth: float | None = None, maximum_depth: float | None = None, vertical_axis: Literal['depth', 'elevation'] = 'depth', start_datetime: datetime.datetime | pandas.Timestamp | str | None = None, end_datetime: datetime.datetime | pandas.Timestamp | str | None = None, minimum_x: float | None = None, maximum_x: float | None = None, minimum_y: float | None = None, maximum_y: float | None = None, coordinates_selection_method: Literal['inside', 'strict-inside', 'nearest', 'outside'] = 'inside', output_filename: str | None = None, file_format: Optional[Literal['netcdf', 'zarr', 'cs
# ...

# %%
import copernicusmarine

copernicusmarine.subset(
  dataset_id="cmems_mod_glo_phy_anfc_0.083deg_P1D-m",
  variables=["tob"],
  minimum_longitude=-86.97478132305312,
  maximum_longitude=-81.37966193301433,
  minimum_latitude=6.920233935776719,
  maximum_latitude=11.411554262474521,
  start_datetime="2022-06-01T00:00:00",
  end_datetime="2026-07-01T00:00:00",
  minimum_depth=0.49402499198913574,
  maximum_depth=0.49402499198913574,
)
# Out:
# INFO - 2026-07-05T20:41:26Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:Copernicus Marine password:
# INFO - 2026-07-05T20:41:52Z - Selected dataset version: "202406"
# INFO - 2026-07-05T20:41:52Z - Selected dataset part: "default"
#   0%|          | [00:00<?]
# INFO - 2026-07-05T20:42:02Z - Total size of the download: 20.23 MB.
# ...
